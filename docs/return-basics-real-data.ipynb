# %% [markdown]
# # Risk Adjusted Returns with Real Data

# %% [markdown]
# ## Retrieve Data for portfolio formed on ME

# %%
import numpy as np
import pandas as pd

import quantopy as qp

# %%
portfolio = qp.portfolio_data.get_portfolio(qp.portfolio_data.FF_Portfolios.Formed_on_ME_EW)
portfolio
# Out:
#             <= 0   Lo 30  Med 40   Hi 30   Lo 20   Qnt 2   Qnt 3   Qnt 4  \
# 1926-07-01   NaN -0.0043  0.0152  0.0268 -0.0057  0.0059  0.0160  0.0147
# 1926-08-01   NaN  0.0374  0.0304  0.0209  0.0360  0.0359  0.0371  0.0161
# 1926-09-01   NaN -0.0107 -0.0054  0.0016 -0.0048 -0.0140  0.0000 -0.0050
# 1926-10-01   NaN -0.0329 -0.0352 -0.0306 -0.0325 -0.0410 -0.0289 -0.0336
# 1926-11-01   NaN -0.0046  0.0382  0.0309 -0.0054  0.0218  0.0341  0.0339
# ...          ...     ...     ...     ...     ...     ...     ...     ...
# 2020-12-01   NaN  0.1070  0.0869  0.0443  0.1114  0.0931  0.0905  0.0605
# 2021-01-01   NaN  0.1881  0.0333 -0.0062  0.2125  0.0764  0.0229  0.0139
# 2021-02-01   NaN  0.1170  0.0764  0.0449  0.1224  0.0887  0.0761  0.0650
# 2021-03-01   NaN  0.0206  0.0222  0.0383  0.0193  0.0216  0.0243  0.0263
# 2021-04-01   NaN  0.0001  0.0283  0.0469 -0.0043  0.0163  0.0321  0.0426
#
#              Hi 20   Lo 10   Dec 2   Dec 3   Dec 4   Dec 5   Dec 6   Dec 7  \
# ...

# %%
from datetime import datetime

end_date = datetime(1926,7, 1)
start_date = datetime.now()

num_months = (start_date.year - end_date.year) * 12 + (start_date.month - end_date.month)

print(num_months)
# Out:
# 1138

# %%
porfolio.astype(float)/100
# Out:
#             <= 0     Lo 30    Med 40     Hi 30     Lo 20     Qnt 2     Qnt 3  \
# 1926-07-01   NaN  0.000014  0.000159  0.000342  0.000037  0.000078  0.000168
# 1926-08-01   NaN  0.000319  0.000277  0.000291  0.000221  0.000351  0.000375
# 1926-09-01   NaN -0.000173 -0.000088  0.000080 -0.000139 -0.000106  0.000005
# 1926-10-01   NaN -0.000294 -0.000328 -0.000279 -0.000256 -0.000393 -0.000267
# 1926-11-01   NaN -0.000038  0.000373  0.000274 -0.000095  0.000294  0.000352
# ...          ...       ...       ...       ...       ...       ...       ...
# 2020-12-01   NaN  0.000917  0.000808  0.000418  0.000884  0.000949  0.000907
# 2021-01-01   NaN  0.001325  0.000264 -0.000083  0.001828  0.000725  0.000223
# 2021-02-01   NaN  0.000833  0.000695  0.000247  0.000658  0.000830  0.000682
# 2021-03-01   NaN  0.000255  0.000215  0.000361  0.000375  0.000132  0.000198
# 2021-04-01   NaN  0.000063  0.000343  0.000545 -0.000063  0.000175  0.000351
#
# ...

# %%
porfolio.iloc[:1139,:]
# Out:
#      Unnamed: 0 <= 0  Lo 30 Med 40  Hi 30  Lo 20  Qnt 2  Qnt 3  Qnt 4  Hi 20  \
# 0        192607  NaN   0.14   1.59   3.42   0.37   0.78   1.68   1.39   3.67
# 1        192608  NaN   3.19   2.77   2.91   2.21   3.51   3.75   1.53   3.07
# 2        192609  NaN  -1.73  -0.88   0.80  -1.39  -1.06   0.05  -0.26   0.81
# 3        192610  NaN  -2.94  -3.28  -2.79  -2.56  -3.93  -2.67  -3.38  -2.74
# 4        192611  NaN  -0.38   3.73   2.74  -0.95   2.94   3.52   3.25   2.71
# ...         ...  ...    ...    ...    ...    ...    ...    ...    ...    ...
# 1134     202101  NaN  13.25   2.64  -0.83  18.28   7.25   2.23   0.63  -0.89
# 1135     202102  NaN   8.33   6.95   2.47   6.58   8.30   6.82   6.74   2.15
# 1136     202103  NaN   2.55   2.15   3.61   3.75   1.32   1.98   2.24   3.74
# 1137     202104  NaN   0.63   3.43   5.45  -0.63   1.75   3.51   4.46   5.51
# 1138        NaN  NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
# ...

# %%
porfolio.iloc[:,0]
# Out:
# 0       192607
# 1       192608
# 2       192609
# 3       192610
# 4       192611
#          ...
# 4745    202012
# 4746    202101
# 4747    202102
# 4748    202103
# 4749    202104
# Name: Unnamed: 0, Length: 4750, dtype: object

# %%
porfolio[porfolio.iloc[:,0].str.contains("Returns") == False].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-3f4e9012ff63> in <module>
# ----> 1 porfolio[porfolio.iloc[:,0].str.contains("Returns") == False].astype(float)
#
# ~/opt/anaconda3/envs/quantopy-dev/lib/python3.9/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5875         else:
#    5876             # else, only a single dtype is given
# -> 5877             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5878             return self._constructor(new_data).__finalize__(self, method="astype")
#    5879
#
# ~/opt/anaconda3/envs/quantopy-dev/lib/python3.9/site-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     629         self, dtype, copy: bool = False, errors: str = "raise"
#     630     ) -> "BlockManager":
# ...

# %%
porfolio.iloc[1137:1139,:].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-f9c86a41fa48> in <module>
# ----> 1 porfolio.iloc[1137:1139,:].astype(float)
#
# ~/opt/anaconda3/envs/quantopy-dev/lib/python3.9/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5875         else:
#    5876             # else, only a single dtype is given
# -> 5877             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5878             return self._constructor(new_data).__finalize__(self, method="astype")
#    5879
#
# ~/opt/anaconda3/envs/quantopy-dev/lib/python3.9/site-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     629         self, dtype, copy: bool = False, errors: str = "raise"
#     630     ) -> "BlockManager":
# --> 631         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     632
# ...

# %%
columns = ['Lo 10', 'Hi 10']
returns = porfolio[columns]
returns.head()
# Out:
#         Lo 10  Hi 10
# 192607  -0.12   3.71
# 192608   1.13   3.79
# 192609   0.59   1.25
# 192610  -4.29  -2.56
# 192611  -3.28   2.40

# %%
prices = pd.DataFrame({
    'stock_1': stock_1_price,
    'stock_2': stock_2_price
})

prices.head()
# Out:
#     stock_1   stock_2
# 0  1.000000  1.000000
# 1  0.997507  1.075500
# 2  1.057637  1.080014
# 3  1.147104  1.181013
# 4  1.195772  1.171141

# %%
prices.plot(title='Stock Prices')
# Out:
# <AxesSubplot:title={'center':'Stock Prices'}>

# %%
rs = qp.returns.returns(prices)

rs.head()
# Out:
#     stock_1   stock_2
# 1 -0.002493  0.075500
# 2  0.060280  0.004197
# 3  0.084591  0.093516
# 4  0.042427 -0.008360
# 5  0.079440  0.131685

# %%
rs.plot.bar(title='Stock Returns')
# Out:
# <AxesSubplot:title={'center':'Stock Returns'}>

# %% [markdown]
# ## Calculate Standard Deviation of returns

# %%
rs.std()
# Out:
# stock_1    0.028121
# stock_2    0.061413
# dtype: float64

# %% [markdown]
# ## Calculate Mean fo the returns

# %%
rs.mean()
# Out:
# stock_1    0.049836
# stock_2    0.067024
# dtype: float64

# %% [markdown]
# ## Annualization

# %% [markdown]
# ## Annual Rate of Return

# %%
qp.returns.effect(rs.mean(), qp.periods.Period.MONTHLY)
# Out:
# stock_1    0.792486
# stock_2    1.178160
# dtype: float64

# %% [markdown]
# ## Annual Volatility

# %%
qp.returns.effect_vol(rs.std(), qp.periods.Period.MONTHLY)
# Out:
# stock_1    0.097414
# stock_2    0.212741
# dtype: float64
