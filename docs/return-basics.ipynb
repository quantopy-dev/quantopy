# %%
import numpy as np
import pandas as pd

from quantopy import returns, simulate

# %%
np.random.seed(0)

# Generate price for 2 stocks
stock_1_price = simulate.stock_price(0.05, 0.03, 50)
stock_2_price = simulate.stock_price(0.05, 0.10, 50)

# %%
prices = pd.DataFrame({
    'stock_1': stock_1_price,
    'stock_2': stock_2_price
})

prices.head()
# Out:
#     stock_1   stock_2
# 0  1.000000  1.000000
# 1  1.102922  1.028726
# 2  1.171308  0.988043
# 3  1.264265  1.075673
# 4  1.412471  1.074511

# %%
prices.plot(title='Stock Prices')
# Out:
# <AxesSubplot:title={'center':'Stock Prices'}>

# %%
rs = returns.returns(prices)

rs.head()
# Out:
#     stock_1   stock_2
# 1  0.102922  0.028726
# 2  0.062005 -0.039547
# 3  0.079362  0.088690
# 4  0.117227 -0.001081
# 5  0.106027 -0.068063

# %%
rs.plot.bar(title='Stock Returns')
# Out:
# <AxesSubplot:title={'center':'Stock Returns'}>

# %% [markdown]
# ## Calculate Standard Deviation of returns

# %%
rs.std()
# Out:
# stock_1    0.034427
# stock_2    0.088288
# dtype: float64

# %% [markdown]
# ## Calculate Mean fo the returns

# %%
rs.mean()
# Out:
# stock_1    0.054433
# stock_2    0.046349
# dtype: float64
